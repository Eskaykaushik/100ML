# %% [markdown]
# <a href="https://colab.research.google.com/github/Eskaykaushik/100ML/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
books=pd.read_csv('Books.csv')

# %%
books
# Out:
#              ISBN                                         Book-Title  \
# 0      0195153448                                Classical Mythology
# 1      0002005018                                       Clara Callan
# 2      0060973129                               Decision in Normandy
# 3      0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4      0393045218                             The Mummies of Urumchi
# ...           ...                                                ...
# 15863  0316353299             Blue Highways : A Journey into America
# 15864  1869503171                                     Spirit Writing
# 15865  0767903862                             In a Sunburned Country
# 15866  0060931671                               The Crying of Lot 49
# 15867  0060730552                                    Touching the Vo
#
#                    Book-Author  Year-Of-Publication  \
# 0           Mark P. O. Morford               2002.0
# 1         Richard Bruce Wright               2001.0
# 2                 Carlo D'Este               1991.0
# 3             Gina Bari Kolata               1999.0
# 4              E. J. W. Barber               1999.0
# ...                        ...                  ...
# 15863  William Least Heat-Moon               1999.0
# 15864          Adrienne Jansen               1999.0
# 15865              Bill Bryson               2001.0
# 15866           Thomas Pynchon               1999.0
# 15867                      NaN                  NaN
#
#                         Publisher  \
# 0         Oxford University Press
# 1           HarperFlamingo Canada
# 2                 HarperPerennial
# 3            Farrar Straus Giroux
# 4      W. W. Norton &amp; Company
# ...                           ...
# 15863              Back Bay Books
# 15864   HarperCollins New Zealand
# 15865              Broadway Books
# 15866          Perennial Classics
# 15867                         NaN
#
#                                              Image-URL-S  \
# 0      http://images.amazon.com/images/P/0195153448.0...
# 1      http://images.amazon.com/images/P/0002005018.0...
# 2      http://images.amazon.com/images/P/0060973129.0...
# 3      http://images.amazon.com/images/P/0374157065.0...
# 4      http://images.amazon.com/images/P/0393045218.0...
# ...                                                  ...
# 15863  http://images.amazon.com/images/P/0316353299.0...
# 15864  http://images.amazon.com/images/P/1869503171.0...
# 15865  http://images.amazon.com/images/P/0767903862.0...
# 15866  http://images.amazon.com/images/P/0060931671.0...
# 15867                                                NaN
#
#                                              Image-URL-M  \
# 0      http://images.amazon.com/images/P/0195153448.0...
# 1      http://images.amazon.com/images/P/0002005018.0...
# 2      http://images.amazon.com/images/P/0060973129.0...
# 3      http://images.amazon.com/images/P/0374157065.0...
# 4      http://images.amazon.com/images/P/0393045218.0...
# ...                                                  ...
# 15863  http://images.amazon.com/images/P/0316353299.0...
# 15864  http://images.amazon.com/images/P/1869503171.0...
# 15865  http://images.amazon.com/images/P/0767903862.0...
# 15866  http://images.amazon.com/images/P/0060931671.0...
# 15867                                                NaN
#
#                                              Image-URL-L
# 0      http://images.amazon.com/images/P/0195153448.0...
# 1      http://images.amazon.com/images/P/0002005018.0...
# 2      http://images.amazon.com/images/P/0060973129.0...
# 3      http://images.amazon.com/images/P/0374157065.0...
# 4      http://images.amazon.com/images/P/0393045218.0...
# ...                                                  ...
# 15863  http://images.amazon.com/images/P/0316353299.0...
# 15864  http://images.amazon.com/images/P/1869503171.0...
# 15865  http://images.amazon.com/images/P/0767903862.0...
# 15866  http://images.amazon.com/images/P/0060931671.0...
# 15867                                                NaN
#
# [15868 rows x 8 columns]

# %%
books.shape
# Out:
# (15868, 8)

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15868 entries, 0 to 15867
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ISBN                 15868 non-null  object
#  1   Book-Title           15868 non-null  object
#  2   Book-Author          15867 non-null  object
#  3   Year-Of-Publication  15867 non-null  float64
#  4   Publisher            15867 non-null  object
#  5   Image-URL-S          15867 non-null  object
#  6   Image-URL-M          15867 non-null  object
#  7   Image-URL-L          15867 non-null  object
# dtypes: float64(1), object(7)
# memory usage: 991.9+ KB

# %%
ratings=pd.read_csv('Ratings.csv')

# %%
ratings
# Out:
#         User-ID        ISBN  Book-Rating
# 0        276725  034545104X          0.0
# 1        276726  0155061224          5.0
# 2        276727  0446520802          0.0
# 3        276729  052165615X          3.0
# 4        276729  0521795028          6.0
# ...         ...         ...          ...
# 221148    51883  0373245475         10.0
# 221149    51883  0373245505          2.0
# 221150    51883  0373245580          0.0
# 221151    51883  0373245599          0.0
# 221152    51883         NaN          NaN
#
# [221153 rows x 3 columns]

# %%
users=pd.read_csv('Users.csv')

# %%
users
# Out:
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 107871   107872            florence, toscana, italy  38.0
# 107872   107873         london, n.a, united kingdom   NaN
# 107873   107874   ankara, centeral anatolia, turkey  22.0
# 107874   107875               segrate, milan, italy  28.0
# 107875       10                                 NaN   NaN
#
# [107876 rows x 3 columns]

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X          0.0
# 1   276726  0155061224          5.0
# 2   276727  0446520802          0.0
# 3   276729  052165615X          3.0
# 4   276729  0521795028          6.0

# %%
users.shape
# Out:
# (107876, 3)

# %%
ratings.shape
# Out:
# (221153, 3)

# %%
books.shape
# Out:
# (15868, 8)

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    1
# Publisher              1
# Image-URL-S            1
# Image-URL-M            1
# Image-URL-L            1
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID         0
# Location        1
# Age         42838
# dtype: int64

# %%
books.duplicated().sum()
# Out:
# 0

# %%
ratings.duplicated().sum()
# Out:
# 0

# %%
users.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Popularity Based

# %%
temp1=ratings.merge(books,on='ISBN')

# %%
temp1
# Out:
#        User-ID        ISBN  Book-Rating  \
# 0       276725  034545104X          0.0
# 1         2313  034545104X          5.0
# 2         6543  034545104X          0.0
# 3         8680  034545104X          5.0
# 4        10314  034545104X          9.0
# ...        ...         ...          ...
# 77003    38781  0373224648          0.0
# 77004    35857  0871130297          0.0
# 77005    35859  0843950552          0.0
# 77006    45430  0312974620          0.0
# 77007    47779  0152024999          9.0
#
#                                               Book-Title        Book-Author  \
# 0                                   Flesh Tones: A Novel         M. J. Rose
# 1                                   Flesh Tones: A Novel         M. J. Rose
# 2                                   Flesh Tones: A Novel         M. J. Rose
# 3                                   Flesh Tones: A Novel         M. J. Rose
# 4                                   Flesh Tones: A Novel         M. J. Rose
# ...                                                  ...                ...
# 77003       Heat Of Passion (Harlequin Intrigue, No 464)          Alice Orr
# 77004                                 The God of Mirrors      Robert Reilly
# 77005                      The Infinite (Leisure Horror)         Doug Clegg
# 77006  Beyond Jennifer &amp; Jason, Madison &amp; Mon...  Linda Rosenkrantz
# 77007                                         Ginger Pye      Eleanor Estes
#
#        Year-Of-Publication                Publisher  \
# 0                   2002.0         Ballantine Books
# 1                   2002.0         Ballantine Books
# 2                   2002.0         Ballantine Books
# 3                   2002.0         Ballantine Books
# 4                   2002.0         Ballantine Books
# ...                    ...                      ...
# 77003               1998.0                Harlequin
# 77004               1986.0   Atlantic Monthly Press
# 77005               2002.0            Leisure Books
# 77006               2000.0  St. Martin's Paperbacks
# 77007               2000.0  Harcourt Young Classics
#
#                                              Image-URL-S  \
# 0      http://images.amazon.com/images/P/034545104X.0...
# 1      http://images.amazon.com/images/P/034545104X.0...
# 2      http://images.amazon.com/images/P/034545104X.0...
# 3      http://images.amazon.com/images/P/034545104X.0...
# 4      http://images.amazon.com/images/P/034545104X.0...
# ...                                                  ...
# 77003  http://images.amazon.com/images/P/0373224648.0...
# 77004  http://images.amazon.com/images/P/0871130297.0...
# 77005  http://images.amazon.com/images/P/0843950552.0...
# 77006  http://images.amazon.com/images/P/0312974620.0...
# 77007  http://images.amazon.com/images/P/0152024999.0...
#
#                                              Image-URL-M  \
# 0      http://images.amazon.com/images/P/034545104X.0...
# 1      http://images.amazon.com/images/P/034545104X.0...
# 2      http://images.amazon.com/images/P/034545104X.0...
# 3      http://images.amazon.com/images/P/034545104X.0...
# 4      http://images.amazon.com/images/P/034545104X.0...
# ...                                                  ...
# 77003  http://images.amazon.com/images/P/0373224648.0...
# 77004  http://images.amazon.com/images/P/0871130297.0...
# 77005  http://images.amazon.com/images/P/0843950552.0...
# 77006  http://images.amazon.com/images/P/0312974620.0...
# 77007  http://images.amazon.com/images/P/0152024999.0...
#
#                                              Image-URL-L
# 0      http://images.amazon.com/images/P/034545104X.0...
# 1      http://images.amazon.com/images/P/034545104X.0...
# 2      http://images.amazon.com/images/P/034545104X.0...
# 3      http://images.amazon.com/images/P/034545104X.0...
# 4      http://images.amazon.com/images/P/034545104X.0...
# ...                                                  ...
# 77003  http://images.amazon.com/images/P/0373224648.0...
# 77004  http://images.amazon.com/images/P/0871130297.0...
# 77005  http://images.amazon.com/images/P/0843950552.0...
# 77006  http://images.amazon.com/images/P/0312974620.0...
# 77007  http://images.amazon.com/images/P/0152024999.0...
#
# [77008 rows x 10 columns]

# %%
ratings_with_name=temp1

# %%
def convert_to_numeric(value):
    try:
        return float(value)
    except ValueError:
        return 0

# %%
ratings_with_name['Book-Rating'] = ratings_with_name['Book-Rating'].apply(convert_to_numeric)

# %%
num_rating_df=ratings_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()

# %%
num_rating_df.rename(columns={'Book-Rating':'num-ratings'},inplace=True)

# %%
num_rating_df
# Out:
#                                            Book-Title  num-ratings
# 0                                        It Takes Two            2
# 1                        Tales of Terror and Suspense            1
# 2                                                 '48            1
# 3                                        'Salem's Lot            3
# 4             .Hack: //Legend of the Twilight, Vol. 1            4
# ...                                               ...          ...
# 14965  metamorfosis, La (ClÃ¡sicos selecciÃ³n series)            1
# 14966                                        stardust            9
# 14967                Â¿QuiÃ©n se ha llevado mi queso?            1
# 14968                        Â¿QuÃ© me quieres, amor?            2
# 14969                           Ã?Â?ber die Freiheit.            1
#
# [14970 rows x 2 columns]

# %%
ratings_with_name['Book-Rating'].fillna(0, inplace=True)

# %%
ratings_with_name
# Out:
#        User-ID        ISBN  Book-Rating  \
# 0       276725  034545104X          0.0
# 1         2313  034545104X          5.0
# 2         6543  034545104X          0.0
# 3         8680  034545104X          5.0
# 4        10314  034545104X          9.0
# ...        ...         ...          ...
# 77003    38781  0373224648          0.0
# 77004    35857  0871130297          0.0
# 77005    35859  0843950552          0.0
# 77006    45430  0312974620          0.0
# 77007    47779  0152024999          9.0
#
#                                               Book-Title        Book-Author  \
# 0                                   Flesh Tones: A Novel         M. J. Rose
# 1                                   Flesh Tones: A Novel         M. J. Rose
# 2                                   Flesh Tones: A Novel         M. J. Rose
# 3                                   Flesh Tones: A Novel         M. J. Rose
# 4                                   Flesh Tones: A Novel         M. J. Rose
# ...                                                  ...                ...
# 77003       Heat Of Passion (Harlequin Intrigue, No 464)          Alice Orr
# 77004                                 The God of Mirrors      Robert Reilly
# 77005                      The Infinite (Leisure Horror)         Doug Clegg
# 77006  Beyond Jennifer &amp; Jason, Madison &amp; Mon...  Linda Rosenkrantz
# 77007                                         Ginger Pye      Eleanor Estes
#
#        Year-Of-Publication                Publisher  \
# 0                   2002.0         Ballantine Books
# 1                   2002.0         Ballantine Books
# 2                   2002.0         Ballantine Books
# 3                   2002.0         Ballantine Books
# 4                   2002.0         Ballantine Books
# ...                    ...                      ...
# 77003               1998.0                Harlequin
# 77004               1986.0   Atlantic Monthly Press
# 77005               2002.0            Leisure Books
# 77006               2000.0  St. Martin's Paperbacks
# 77007               2000.0  Harcourt Young Classics
#
#                                              Image-URL-S  \
# 0      http://images.amazon.com/images/P/034545104X.0...
# 1      http://images.amazon.com/images/P/034545104X.0...
# 2      http://images.amazon.com/images/P/034545104X.0...
# 3      http://images.amazon.com/images/P/034545104X.0...
# 4      http://images.amazon.com/images/P/034545104X.0...
# ...                                                  ...
# 77003  http://images.amazon.com/images/P/0373224648.0...
# 77004  http://images.amazon.com/images/P/0871130297.0...
# 77005  http://images.amazon.com/images/P/0843950552.0...
# 77006  http://images.amazon.com/images/P/0312974620.0...
# 77007  http://images.amazon.com/images/P/0152024999.0...
#
#                                              Image-URL-M  \
# 0      http://images.amazon.com/images/P/034545104X.0...
# 1      http://images.amazon.com/images/P/034545104X.0...
# 2      http://images.amazon.com/images/P/034545104X.0...
# 3      http://images.amazon.com/images/P/034545104X.0...
# 4      http://images.amazon.com/images/P/034545104X.0...
# ...                                                  ...
# 77003  http://images.amazon.com/images/P/0373224648.0...
# 77004  http://images.amazon.com/images/P/0871130297.0...
# 77005  http://images.amazon.com/images/P/0843950552.0...
# 77006  http://images.amazon.com/images/P/0312974620.0...
# 77007  http://images.amazon.com/images/P/0152024999.0...
#
#                                              Image-URL-L
# 0      http://images.amazon.com/images/P/034545104X.0...
# 1      http://images.amazon.com/images/P/034545104X.0...
# 2      http://images.amazon.com/images/P/034545104X.0...
# 3      http://images.amazon.com/images/P/034545104X.0...
# 4      http://images.amazon.com/images/P/034545104X.0...
# ...                                                  ...
# 77003  http://images.amazon.com/images/P/0373224648.0...
# 77004  http://images.amazon.com/images/P/0871130297.0...
# 77005  http://images.amazon.com/images/P/0843950552.0...
# 77006  http://images.amazon.com/images/P/0312974620.0...
# 77007  http://images.amazon.com/images/P/0152024999.0...
#
# [77008 rows x 10 columns]

# %%
ratings_with_name['Book-Rating'] = pd.to_numeric(ratings_with_name['Book-Rating'], errors='coerce').fillna(0).astype(int)

# %%
ratings_with_name
# Out:
#        User-ID        ISBN  Book-Rating  \
# 0       276725  034545104X            0
# 1         2313  034545104X            5
# 2         6543  034545104X            0
# 3         8680  034545104X            5
# 4        10314  034545104X            9
# ...        ...         ...          ...
# 77003    38781  0373224648            0
# 77004    35857  0871130297            0
# 77005    35859  0843950552            0
# 77006    45430  0312974620            0
# 77007    47779  0152024999            9
#
#                                               Book-Title        Book-Author  \
# 0                                   Flesh Tones: A Novel         M. J. Rose
# 1                                   Flesh Tones: A Novel         M. J. Rose
# 2                                   Flesh Tones: A Novel         M. J. Rose
# 3                                   Flesh Tones: A Novel         M. J. Rose
# 4                                   Flesh Tones: A Novel         M. J. Rose
# ...                                                  ...                ...
# 77003       Heat Of Passion (Harlequin Intrigue, No 464)          Alice Orr
# 77004                                 The God of Mirrors      Robert Reilly
# 77005                      The Infinite (Leisure Horror)         Doug Clegg
# 77006  Beyond Jennifer &amp; Jason, Madison &amp; Mon...  Linda Rosenkrantz
# 77007                                         Ginger Pye      Eleanor Estes
#
#        Year-Of-Publication                Publisher  \
# 0                   2002.0         Ballantine Books
# 1                   2002.0         Ballantine Books
# 2                   2002.0         Ballantine Books
# 3                   2002.0         Ballantine Books
# 4                   2002.0         Ballantine Books
# ...                    ...                      ...
# 77003               1998.0                Harlequin
# 77004               1986.0   Atlantic Monthly Press
# 77005               2002.0            Leisure Books
# 77006               2000.0  St. Martin's Paperbacks
# 77007               2000.0  Harcourt Young Classics
#
#                                              Image-URL-S  \
# 0      http://images.amazon.com/images/P/034545104X.0...
# 1      http://images.amazon.com/images/P/034545104X.0...
# 2      http://images.amazon.com/images/P/034545104X.0...
# 3      http://images.amazon.com/images/P/034545104X.0...
# 4      http://images.amazon.com/images/P/034545104X.0...
# ...                                                  ...
# 77003  http://images.amazon.com/images/P/0373224648.0...
# 77004  http://images.amazon.com/images/P/0871130297.0...
# 77005  http://images.amazon.com/images/P/0843950552.0...
# 77006  http://images.amazon.com/images/P/0312974620.0...
# 77007  http://images.amazon.com/images/P/0152024999.0...
#
#                                              Image-URL-M  \
# 0      http://images.amazon.com/images/P/034545104X.0...
# 1      http://images.amazon.com/images/P/034545104X.0...
# 2      http://images.amazon.com/images/P/034545104X.0...
# 3      http://images.amazon.com/images/P/034545104X.0...
# 4      http://images.amazon.com/images/P/034545104X.0...
# ...                                                  ...
# 77003  http://images.amazon.com/images/P/0373224648.0...
# 77004  http://images.amazon.com/images/P/0871130297.0...
# 77005  http://images.amazon.com/images/P/0843950552.0...
# 77006  http://images.amazon.com/images/P/0312974620.0...
# 77007  http://images.amazon.com/images/P/0152024999.0...
#
#                                              Image-URL-L
# 0      http://images.amazon.com/images/P/034545104X.0...
# 1      http://images.amazon.com/images/P/034545104X.0...
# 2      http://images.amazon.com/images/P/034545104X.0...
# 3      http://images.amazon.com/images/P/034545104X.0...
# 4      http://images.amazon.com/images/P/034545104X.0...
# ...                                                  ...
# 77003  http://images.amazon.com/images/P/0373224648.0...
# 77004  http://images.amazon.com/images/P/0871130297.0...
# 77005  http://images.amazon.com/images/P/0843950552.0...
# 77006  http://images.amazon.com/images/P/0312974620.0...
# 77007  http://images.amazon.com/images/P/0152024999.0...
#
# [77008 rows x 10 columns]

# %%
avg_rating_df = ratings_with_name.groupby('Book-Title')['Book-Rating'].mean(numeric_only=True).reset_index()
avg_rating_df.rename(columns={'Book-Rating':'avg_rating'},inplace=True)
avg_rating_df
# Out:
#                                            Book-Title  avg_rating
# 0                                        It Takes Two    0.000000
# 1                        Tales of Terror and Suspense    0.000000
# 2                                                 '48    0.000000
# 3                                        'Salem's Lot    3.333333
# 4             .Hack: //Legend of the Twilight, Vol. 1    6.500000
# ...                                               ...         ...
# 14965  metamorfosis, La (ClÃ¡sicos selecciÃ³n series)    8.000000
# 14966                                        stardust    1.777778
# 14967                Â¿QuiÃ©n se ha llevado mi queso?    7.000000
# 14968                        Â¿QuÃ© me quieres, amor?    3.000000
# 14969                           Ã?Â?ber die Freiheit.    7.000000
#
# [14970 rows x 2 columns]

# %%
num_rating_df
# Out:
#                                            Book-Title  num-ratings
# 0                                        It Takes Two            2
# 1                        Tales of Terror and Suspense            1
# 2                                                 '48            1
# 3                                        'Salem's Lot            3
# 4             .Hack: //Legend of the Twilight, Vol. 1            4
# ...                                               ...          ...
# 14965  metamorfosis, La (ClÃ¡sicos selecciÃ³n series)            1
# 14966                                        stardust            9
# 14967                Â¿QuiÃ©n se ha llevado mi queso?            1
# 14968                        Â¿QuÃ© me quieres, amor?            2
# 14969                           Ã?Â?ber die Freiheit.            1
#
# [14970 rows x 2 columns]

# %%
avg_rating_df
# Out:
#                                            Book-Title  avg_rating
# 0                                        It Takes Two    0.000000
# 1                        Tales of Terror and Suspense    0.000000
# 2                                                 '48    0.000000
# 3                                        'Salem's Lot    3.333333
# 4             .Hack: //Legend of the Twilight, Vol. 1    6.500000
# ...                                               ...         ...
# 14965  metamorfosis, La (ClÃ¡sicos selecciÃ³n series)    8.000000
# 14966                                        stardust    1.777778
# 14967                Â¿QuiÃ©n se ha llevado mi queso?    7.000000
# 14968                        Â¿QuÃ© me quieres, amor?    3.000000
# 14969                           Ã?Â?ber die Freiheit.    7.000000
#
# [14970 rows x 2 columns]

# %%
popular_df=num_rating_df.merge(avg_rating_df,on='Book-Title')

# %%
popular_df
# Out:
#                                            Book-Title  num-ratings  avg_rating
# 0                                        It Takes Two            2    0.000000
# 1                        Tales of Terror and Suspense            1    0.000000
# 2                                                 '48            1    0.000000
# 3                                        'Salem's Lot            3    3.333333
# 4             .Hack: //Legend of the Twilight, Vol. 1            4    6.500000
# ...                                               ...          ...         ...
# 14965  metamorfosis, La (ClÃ¡sicos selecciÃ³n series)            1    8.000000
# 14966                                        stardust            9    1.777778
# 14967                Â¿QuiÃ©n se ha llevado mi queso?            1    7.000000
# 14968                        Â¿QuÃ© me quieres, amor?            2    3.000000
# 14969                           Ã?Â?ber die Freiheit.            1    7.000000
#
# [14970 rows x 3 columns]

# %%
popular_df[popular_df['num-ratings']>=100].sort_values('avg_rating',ascending=False)
# Out:
#                                               Book-Title  num-ratings  \
# 13733                              To Kill a Mockingbird          109
# 4883    Harry Potter and the Chamber of Secrets (Book 2)          113
# 12877                            The Secret Life of Bees          131
# 11214                                  The Da Vinci Code          172
# 12156                          The Lovely Bones: A Novel          256
# 4888   Harry Potter and the Sorcerer's Stone (Harry P...          110
# 13706                                           Timeline          105
# 893                                  Angels &amp; Demons          128
# 12700                The Red Tent (Bestselling Backlist)          151
# 14528  Where the Heart Is (Oprah's Book Club (Paperba...          127
# 13073                                        The Summons          111
# 12362                         The Nanny Diaries: A Novel          154
# 4564                           Girl with a Pearl Earring          109
# 10242                                     Summer Sisters          116
# 12425                                       The Notebook          119
# 6552                                          Life of Pi          126
# 9808                              Snow Falling on Cedars          123
# 12550                         The Pilot's Wife : A Novel          107
# 12567                      The Poisonwood Bible: A Novel          104
# 3168     Divine Secrets of the Ya-Ya Sisterhood: A Novel          158
# 319                                      A Painted House          170
# 11508                                           The Firm          112
# 9561   She's Come Undone (Oprah's Book Club (Paperback))          102
# 5223                               House of Sand and Fog          123
# 11634            The Girls' Guide to Hunting and Fishing          102
# 12500                                  The Pelican Brief          124
# 11934                                  The Joy Luck Club          104
# 13134                                      The Testament          109
# 1676                               Bridget Jones's Diary          152
# 11071                                         The Client          106
# 14619                                        Wild Animus          465
#
#        avg_rating
# 13733    5.119266
# 4883     5.088496
# 12877    5.083969
# 11214    4.622093
# 12156    4.589844
# 4888     4.545455
# 13706    4.323810
# 893      4.250000
# 12700    4.225166
# 14528    4.181102
# 13073    4.180180
# 12362    3.915584
# 4564     3.862385
# 10242    3.862069
# 12425    3.840336
# 6552     3.801587
# 9808     3.747967
# 12550    3.607477
# 12567    3.567308
# 3168     3.512658
# 319      3.400000
# 11508    3.366071
# 9561     3.303922
# 5223     3.292683
# 11634    3.264706
# 12500    3.233871
# 11934    3.230769
# 13134    3.128440
# 1676     3.125000
# 11071    3.000000
# 14619    1.079570
